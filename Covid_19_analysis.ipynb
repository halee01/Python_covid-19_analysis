# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url='https://raw.githubusercontent.com/MachineLearnia/Python-Machine-Learning/master/Dataset/dataset.csv'
data = pd.read_csv(url,index_col=0,encoding = "ISO-8859-1")

# %%
data.head()
# Out:
#                  Patient age quantile SARS-Cov-2 exam result  \
# Patient ID
# 44477f75e8169d2                    13               negative
# 126e9dd13932f68                    17               negative
# a46b4402a0e5696                     8               negative
# f7d619a94f97c45                     5               negative
# d9e41465789c2b5                    15               negative
#
#                  Patient addmited to regular ward (1=yes, 0=no)  \
# Patient ID
# 44477f75e8169d2                                               0
# 126e9dd13932f68                                               0
# a46b4402a0e5696                                               0
# f7d619a94f97c45                                               0
# d9e41465789c2b5                                               0
#
#                  Patient addmited to semi-intensive unit (1=yes, 0=no)  \
# Patient ID
# 44477f75e8169d2                                                  0
# ...

# %%
df=data.copy()
df.shape
# Out:
# (5644, 110)

# %% [markdown]
# Types de variables : qualitatives70 , quantitatives :41

# %%
df.dtypes
# Out:
# Patient age quantile                                       int64
# SARS-Cov-2 exam result                                    object
# Patient addmited to regular ward (1=yes, 0=no)             int64
# Patient addmited to semi-intensive unit (1=yes, 0=no)      int64
# Patient addmited to intensive care unit (1=yes, 0=no)      int64
#                                                           ...
# HCO3 (arterial blood gas analysis)                       float64
# pO2 (arterial blood gas analysis)                        float64
# Arteiral Fio2                                            float64
# Phosphor                                                 float64
# ctO2 (arterial blood gas analysis)                       float64
# Length: 110, dtype: object

# %%
df.dtypes.value_counts()
# Out:
# float64    70
# object     36
# int64       4
# Name: count, dtype: int64

# %%
df.isna().sum()/df.shape[0]
# Out:
# Patient age quantile                                     0.000000
# SARS-Cov-2 exam result                                   0.000000
# Patient addmited to regular ward (1=yes, 0=no)           0.000000
# Patient addmited to semi-intensive unit (1=yes, 0=no)    0.000000
# Patient addmited to intensive care unit (1=yes, 0=no)    0.000000
#                                                            ...
# HCO3 (arterial blood gas analysis)                       0.995216
# pO2 (arterial blood gas analysis)                        0.995216
# Arteiral Fio2                                            0.996456
# Phosphor                                                 0.996456
# ctO2 (arterial blood gas analysis)                       0.995216
# Length: 110, dtype: float64

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.isna(),cbar=False)
# Out:
# <Axes: ylabel='Patient ID'>

# %% [markdown]
# examen de la colonne target

# %%
df['SARS-Cov-2 exam result'].value_counts(normalize=True)
# Out:
# SARS-Cov-2 exam result
# negative    0.901134
# positive    0.098866
# Name: proportion, dtype: float64

# %% [markdown]
# 90% du dataset(patients) détectes positif

# %% [markdown]
# Visualisation initiale - ELIMINATION DES COLONNES INUTILES

# %%
df=df[df.columns[df.isna().sum()-df.shape[0]< 0.9]]
df.head()
# Out:
#                  Patient age quantile SARS-Cov-2 exam result  \
# Patient ID
# 44477f75e8169d2                    13               negative
# 126e9dd13932f68                    17               negative
# a46b4402a0e5696                     8               negative
# f7d619a94f97c45                     5               negative
# d9e41465789c2b5                    15               negative
#
#                  Patient addmited to regular ward (1=yes, 0=no)  \
# Patient ID
# 44477f75e8169d2                                               0
# 126e9dd13932f68                                               0
# a46b4402a0e5696                                               0
# f7d619a94f97c45                                               0
# d9e41465789c2b5                                               0
#
#                  Patient addmited to semi-intensive unit (1=yes, 0=no)  \
# Patient ID
# 44477f75e8169d2                                                  0
# ...

# %%
df.shape
# Out:
# (5644, 110)

# %% [markdown]
# Histogrammes des variables continues

# %%
for col in df.select_dtypes('float'):
  plt.figure()
  sns.displot(df[col])
# Out:
# <ipython-input-42-2f082ceac277>:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure()
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-42-2f082ceac277> in <cell line: 1>()
#       1 for col in df.select_dtypes('float'):
#       2   plt.figure()
# ----> 3   sns.displot(df[col])
#
# /usr/local/lib/python3.10/dist-packages/seaborn/distributions.py in displot(data, x, y, hue, row, col, weights, kind, rug, rug_kws, log_scale, legend, palette, hue_order, hue_norm, color, col_wrap, row_order, col_order, height, aspect, facet_kws, **kwargs)
#    2264     )
#    2265     g.set_titles()
# ...

# %%
sns.displot(df['Patient age quantile' ],bins = 20)
df['Patient age quantile'].value_counts()
# Out:
# Patient age quantile
# 11    380
# 4     366
# 9     359
# 0     334
# 7     319
# 2     315
# 13    313
# 14    299
# 5     294
# 6     281
# 16    279
# 19    275
# 15    269
# 17    263
# 18    259
# 3     251
# 1     234
# 12    197
# 10    190
# 8     167
# Name: count, dtype: int64

# %%
for col in df.select_dtypes('object'):
    print(f'{col :-<50} {df[col].unique()}')
# Out:
# SARS-Cov-2 exam result---------------------------- ['negative' 'positive']
# Respiratory Syncytial Virus----------------------- [nan 'not_detected' 'detected']
# Influenza A--------------------------------------- [nan 'not_detected' 'detected']
# Influenza B--------------------------------------- [nan 'not_detected' 'detected']
# Parainfluenza 1----------------------------------- [nan 'not_detected' 'detected']
# CoronavirusNL63----------------------------------- [nan 'not_detected' 'detected']
# Rhinovirus/Enterovirus---------------------------- [nan 'detected' 'not_detected']
# Coronavirus HKU1---------------------------------- [nan 'not_detected' 'detected']
# Parainfluenza 3----------------------------------- [nan 'not_detected' 'detected']
# Chlamydophila pneumoniae-------------------------- [nan 'not_detected' 'detected']
# Adenovirus---------------------------------------- [nan 'not_detected' 'detected']
# ...

# %%
for col in df.select_dtypes('object'):
    plt.figure()
    df[col].value_counts().plot.pie()
    plt.title(col)
# Out:
# <ipython-input-47-e66b54081b23>:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure()

# %% [markdown]
# Relatyion target/ variables

# %% [markdown]
# creation des sous ensembles pos et neg

# %%
positive_df=df[df['SARS-Cov-2 exam result']=='positive']
negative_df=df[df['SARS-Cov-2 exam result']=='negative']

# %% [markdown]
# creation des ensembles blood et viral

# %%
missing_rate_df=df.isna().sum()/df.shape[0]
missing_rate_df
# Out:
# Patient age quantile                                     0.000000
# SARS-Cov-2 exam result                                   0.000000
# Patient addmited to regular ward (1=yes, 0=no)           0.000000
# Patient addmited to semi-intensive unit (1=yes, 0=no)    0.000000
# Patient addmited to intensive care unit (1=yes, 0=no)    0.000000
#                                                            ...
# HCO3 (arterial blood gas analysis)                       0.995216
# pO2 (arterial blood gas analysis)                        0.995216
# Arteiral Fio2                                            0.996456
# Phosphor                                                 0.996456
# ctO2 (arterial blood gas analysis)                       0.995216
# Length: 110, dtype: float64
